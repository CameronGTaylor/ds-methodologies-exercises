# %%
import wrangle_zillow
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df = wrangle_zillow.get_zillow_data()

# %%
df.shape
# Out:
# (77381, 67)

# %%
df.head(2)
# Out:
#    parcelid transactiondate  typeconstructiontypeid  storytypeid  \
# 0  10711855      2017-07-07                     NaN          NaN
# 1  10711877      2017-08-29                     NaN          NaN
#
#    propertylandusetypeid  heatingorsystemtypeid  buildingclasstypeid  \
# 0                  261.0                    NaN                  NaN
# 1                  261.0                    NaN                  NaN
#
#    architecturalstyletypeid  airconditioningtypeid  logerror  ...  \
# 0                       NaN                    NaN  0.025595  ...
# 1                       NaN                    NaN  0.055619  ...
#
#    taxdelinquencyflag  taxdelinquencyyear  censustractandblock  \
# 0                None                 NaN         6.059063e+13
# 1                None                 NaN         6.111001e+13
#
#    airconditioningdesc  architecturalstyledesc  buildingclassdesc  \
# 0                 None                    None               None
# ...

# %%
df = wrangle_zillow.handle_missing_values(df)
df.shape
# Out:
# /Users/camerontaylor/codeup-data-science/ds-methodologies-exercises/clustering/wrangle_zillow.py:51: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.dropna(axis=1, thresh=threshold, inplace=True)
# /Users/camerontaylor/codeup-data-science/ds-methodologies-exercises/clustering/wrangle_zillow.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.dropna(axis=0, thresh=threshold, inplace=True)
# (52387, 28)

# %%
df = wrangle_zillow.extra_clean(df)

# %%
df.head()
# Out:
#           calculatedfinishedsquarefeet_x  fullbathcnt_x  lotsizesquarefeet_x  \
# parcelid
# 10711855                            3100              3                 4506
# 10711877                            1465              1                12647
# 10711888                            1243              2                 8432
# 10711910                            2376              3                13038
# 10711956                            2962              3                63000
#
#           regionidcity_x  regionidzip_x  yearbuilt_x  \
# parcelid
# 10711855           53571          96978         1998
# 10711877           13091          97099         1967
# 10711888           21412          97078         1962
# 10711910          396551          96330         1970
# 10711956           47019          96293         1950
#
#           structuretaxvaluedollarcnt_x  taxvaluedollarcnt_x  \
# parcelid
# 10711855                      485713.0            1023282.0
# ...

# %%
sns.pairplot(df, corner=True)

# %%
df.regionidcity_x.value_counts()
# Out:
# 12447    11405
# 5534      1806
# 40227     1497
# 46298     1424
# 16764     1087
#          ...
# 19034        1
# 27166        1
# 22872        1
# 28797        1
# 12358        1
# Name: regionidcity_x, Length: 826, dtype: int64

# %%
sns.scatterplot(df.longitude,df.latitude)
